# %%
import logging
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup

logging.basicConfig(
    format='%(asctime)s %(levelname)s:%(message)s',
    level=logging.INFO)

# NOTES:
# No parallelism offered
# No retries

class Crawler:
    def __init__(self, urls=[]):
        self.visited_urls = []
        self.urls_to_visit = urls
        
    def download_url(self, url):
        return requests.get(url).text
    
    def get_linked_urls(self, url, html):
        soup = BeautifulSoup(html, 'html.parser')
        # get all links in the page using the <a href> tag
        for link in soup.find_all('a'):
            path = link.get('href')
            if path and path.startswith('/'):
                path = urljoin(url, path)
            yield path
            
    def add_url_to_visit(self, url):
        if url not in self.visited_urls and url not in self.urls_to_visit:
            self.urls_to_visit.append(url)
            
    def crawl(self, url):
        html = self.download_url(url)
        for url in self.get_linked_urls(url, html):
            self.add_url_to_visit(url)
            
    def run(self):
        while self.urls_to_visit:
            url = self.urls_to_visit.pop(0)
            logging.info(f'Crawling: {url}')
            try:
                self.crawl(url)
            except Exception:
                logging.exception(f'Failed to crawl: {url}')
            finally:
                self.visited_urls.append(url)
                
if __name__ == '__main__':
    Crawler(urls=['https://www.imbd.com/']).run()
# Out:
# 2023-10-28 08:16:46,321 INFO:Crawling: https://www.imbd.com/
# 2023-10-28 08:16:46,602 INFO:Crawling: #page-top
# 2023-10-28 08:16:46,603 ERROR:Failed to crawl: #page-top
# Traceback (most recent call last):
#   File "<ipython-input-2-e7734c85d5c6>", line 41, in run
#     self.crawl(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 32, in crawl
#     html = self.download_url(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 16, in download_url
#     return requests.get(url).text
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 575, in request
#     prep = self.prepare_request(req)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 486, in prepare_request
#     p.prepare(
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '#page-top': No scheme supplied. Perhaps you meant https://#page-top?
# 2023-10-28 08:16:46,604 INFO:Crawling: None
# 2023-10-28 08:16:46,605 ERROR:Failed to crawl: None
# Traceback (most recent call last):
#   File "<ipython-input-2-e7734c85d5c6>", line 41, in run
#     self.crawl(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 32, in crawl
#     html = self.download_url(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 16, in download_url
#     return requests.get(url).text
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 575, in request
#     prep = self.prepare_request(req)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 486, in prepare_request
#     p.prepare(
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# 2023-10-28 08:16:46,605 INFO:Crawling: http://softgirls.com/?query=Meet%20Dating%20Site%20Free&afdToken=ChMI_e3EvPKr8wIV8KOLCh2-RQ9tElHcHWDWe8gszL69L47C9MwTN5Kogw_HaRSykw2tf7jmOAf7-OzhqFI1oOq
# 2023-10-28 08:16:46,763 INFO:Crawling: http://coolgirl.com
# 2023-10-28 08:16:46,921 INFO:Crawling: http://adul.com
# 2023-10-28 08:16:47,079 INFO:Crawling: http://sexwomen.com
# 2023-10-28 08:16:47,236 INFO:Crawling: http://xanime.com
# 2023-10-28 08:16:47,392 INFO:Crawling: http://teenchats.com
# 2023-10-28 08:16:47,544 INFO:Crawling: http://eurogirl.com
# 2023-10-28 08:16:47,695 INFO:Crawling: http://nake.com
# 2023-10-28 08:16:47,854 INFO:Crawling: http://sextalks.com
# 2023-10-28 08:16:48,009 INFO:Crawling: http://hotkorean.com
# 2023-10-28 08:16:48,164 INFO:Crawling: http://callescort.com
# 2023-10-28 08:16:48,323 INFO:Crawling: http://orientalexpress.com
# 2023-10-28 08:16:48,478 INFO:Crawling: http://eroticthumbs.com
# 2023-10-28 08:16:48,640 INFO:Crawling: http://ManChart.com
# 2023-10-28 08:16:49,045 INFO:Crawling: http://Gerls.com
# 2023-10-28 08:16:49,200 INFO:Crawling: http://Girl18.com
# 2023-10-28 08:16:49,355 INFO:Crawling: http://KoreanGirls.com
# 2023-10-28 08:16:49,519 INFO:Crawling: http://AmericaGirl.com.com
# 2023-10-28 08:16:49,637 INFO:Crawling: http://PrivateAccount.com
# 2023-10-28 08:16:49,798 INFO:Crawling: http://FreeBankCards.com
# 2023-10-28 08:16:49,960 INFO:Crawling: http://openbankaccount.com
# 2023-10-28 08:16:50,116 INFO:Crawling: http://creditbankcard.com
# 2023-10-28 08:16:50,281 INFO:Crawling: http://bankaccountonline.com
# 2023-10-28 08:16:50,441 INFO:Crawling: http://onlinedebitcards.com
# 2023-10-28 08:16:50,595 INFO:Crawling: http://bestdebitcard.com
# 2023-10-28 08:16:50,747 INFO:Crawling: http://bankaccountcard.com
# 2023-10-28 08:16:50,902 INFO:Crawling: http://instantbanking.com
# 2023-10-28 08:16:51,061 INFO:Crawling: http://stocksresearch.com
# 2023-10-28 08:16:51,219 INFO:Crawling: http://telephonebanking.com
# 2023-10-28 08:16:51,376 INFO:Crawling: http://electronicmails.com
# 2023-10-28 08:16:51,533 INFO:Crawling: #section-615edb1d7fd91
# 2023-10-28 08:16:51,533 ERROR:Failed to crawl: #section-615edb1d7fd91
# Traceback (most recent call last):
#   File "<ipython-input-2-e7734c85d5c6>", line 41, in run
#     self.crawl(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 32, in crawl
#     html = self.download_url(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 16, in download_url
#     return requests.get(url).text
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 575, in request
#     prep = self.prepare_request(req)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 486, in prepare_request
#     p.prepare(
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '#section-615edb1d7fd91': No scheme supplied. Perhaps you meant https://#section-615edb1d7fd91?
# 2023-10-28 08:16:51,534 INFO:Crawling: https://www.facebook.com/
# 2023-10-28 08:16:51,963 INFO:Crawling: https://www.instagram.com/
# 2023-10-28 08:16:52,423 INFO:Crawling: #main
# 2023-10-28 08:16:52,424 ERROR:Failed to crawl: #main
# Traceback (most recent call last):
#   File "<ipython-input-2-e7734c85d5c6>", line 41, in run
#     self.crawl(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 32, in crawl
#     html = self.download_url(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 16, in download_url
#     return requests.get(url).text
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 575, in request
#     prep = self.prepare_request(req)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 486, in prepare_request
#     p.prepare(
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '#main': No scheme supplied. Perhaps you meant https://#main?
# 2023-10-28 08:16:52,425 INFO:Crawling: https://www.HugeDomains.com/index.cfm
# 2023-10-28 08:16:53,359 INFO:Crawling: tel:1-303-893-0552
# 2023-10-28 08:16:53,360 ERROR:Failed to crawl: tel:1-303-893-0552
# Traceback (most recent call last):
#   File "<ipython-input-2-e7734c85d5c6>", line 41, in run
#     self.crawl(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 32, in crawl
#     html = self.download_url(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 16, in download_url
#     return requests.get(url).text
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 697, in send
#     adapter = self.get_adapter(url=request.url)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 794, in get_adapter
#     raise InvalidSchema(f"No connection adapters were found for {url!r}")
# requests.exceptions.InvalidSchema: No connection adapters were found for 'tel:1-303-893-0552'
# 2023-10-28 08:16:53,361 INFO:Crawling: https://www.HugeDomains.com/faq.cfm
# 2023-10-28 08:16:53,648 INFO:Crawling: https://www.HugeDomains.com/about.cfm
# 2023-10-28 08:16:53,899 INFO:Crawling: https://www.HugeDomains.com/contact.cfm
# 2023-10-28 08:16:54,129 INFO:Crawling: https://www.HugeDomains.com/payment-plan-login.cfm
# 2023-10-28 08:16:54,473 INFO:Crawling: https://www.HugeDomains.com/my-favorites.cfm
# 2023-10-28 08:16:54,779 INFO:Crawling: https://www.HugeDomains.com/shopping_cart.cfm
# 2023-10-28 08:16:55,206 INFO:Crawling: https://www.HugeDomains.com/shopping_cart.cfm?d=ManChart&e=com
# 2023-10-28 08:16:55,539 INFO:Crawling: https://www.HugeDomains.com/payment-plan-setup.cfm?d=ManChart.com
# 2023-10-28 08:16:56,019 INFO:Crawling: https://www.HugeDomains.com/testimonials.cfm
# 2023-10-28 08:16:56,431 INFO:Crawling: https://www.HugeDomains.com/case-studies.cfm
# 2023-10-28 08:16:56,668 INFO:Crawling: https://www.HugeDomains.com/case-study-pixelbull.cfm
# 2023-10-28 08:16:56,952 INFO:Crawling: #
# 2023-10-28 08:16:56,953 ERROR:Failed to crawl: #
# Traceback (most recent call last):
#   File "<ipython-input-2-e7734c85d5c6>", line 41, in run
#     self.crawl(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 32, in crawl
#     html = self.download_url(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 16, in download_url
#     return requests.get(url).text
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 575, in request
#     prep = self.prepare_request(req)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 486, in prepare_request
#     p.prepare(
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL '#': No scheme supplied. Perhaps you meant https://#?
# 2023-10-28 08:16:56,954 INFO:Crawling: https://www.HugeDomains.com/transfer-domain-to-godaddy.cfm
# 2023-10-28 08:16:57,195 INFO:Crawling: https://www.HugeDomains.com/payment-plans.cfm?d=ManChart.com
# 2023-10-28 08:16:57,496 INFO:Crawling: https://www.HugeDomains.com/domain_profile.cfm?d=IpChart.com
# 2023-10-28 08:16:57,750 INFO:Crawling: https://www.HugeDomains.com/domain_profile.cfm?d=ChartBoy.com
# 2023-10-28 08:16:57,966 INFO:Crawling: https://www.HugeDomains.com/domain_profile.cfm?d=IcsChart.com
# 2023-10-28 08:16:58,230 INFO:Crawling: https://www.HugeDomains.com/domain_search.cfm?domain_name=Man
# 2023-10-28 08:16:59,360 INFO:Crawling: https://www.HugeDomains.com/domain_search.cfm?domain_name=Chart
# 2023-10-28 08:16:59,995 INFO:Crawling: https://www.HugeDomains.com/categories.cfm
# 2023-10-28 08:17:00,324 INFO:Crawling: https://www.HugeDomains.com/payment-plans.cfm
# 2023-10-28 08:17:00,638 INFO:Crawling: https://www.HugeDomains.com/satisfaction_guaranteed.cfm
# 2023-10-28 08:17:00,899 INFO:Crawling: https://www.HugeDomains.com/escrow.cfm
# 2023-10-28 08:17:01,160 INFO:Crawling: https://www.HugeDomains.com/namebright.cfm
# 2023-10-28 08:17:01,419 INFO:Crawling: https://www.HugeDomains.com/buying_guide.cfm
# 2023-10-28 08:17:01,746 INFO:Crawling: https://www.HugeDomains.com/terms.cfm
# 2023-10-28 08:17:02,056 INFO:Crawling: https://www.HugeDomains.com/privacy_policy.cfm
# 2023-10-28 08:17:02,327 INFO:Crawling: https://www.HugeDomains.com/get-domain.cfm
# 2023-10-28 08:17:02,568 INFO:Crawling: https://www.facebook.com/recover/initiate/?privacy_mutation_token=eyJ0eXBlIjowLCJjcmVhdGlvbl90aW1lIjoxNjk4NTAyNjEyLCJjYWxsc2l0ZV9pZCI6MzgxMjI5MDc5NTc1OTQ2fQ%3D%3D&ars=facebook_login
# 2023-10-28 08:17:02,982 INFO:Crawling: https://www.facebook.com/pages/create/?ref_type=registration_form
# 2023-10-28 08:17:03,283 INFO:Crawling: https://es-la.facebook.com/
# 2023-10-28 08:17:03,626 INFO:Crawling: https://fr-fr.facebook.com/
# 2023-10-28 08:17:04,010 INFO:Crawling: https://zh-cn.facebook.com/
# 2023-10-28 08:17:04,454 INFO:Crawling: https://ar-ar.facebook.com/
# 2023-10-28 08:17:04,808 INFO:Crawling: https://pt-br.facebook.com/
# 2023-10-28 08:17:05,173 INFO:Crawling: https://it-it.facebook.com/
# 2023-10-28 08:17:05,689 INFO:Crawling: https://ko-kr.facebook.com/
# 2023-10-28 08:17:06,499 INFO:Crawling: https://de-de.facebook.com/
# 2023-10-28 08:17:06,868 INFO:Crawling: https://hi-in.facebook.com/
# 2023-10-28 08:17:07,566 INFO:Crawling: https://ja-jp.facebook.com/
# 2023-10-28 08:17:08,045 INFO:Crawling: https://www.facebook.com/reg/
# 2023-10-28 08:17:08,407 INFO:Crawling: https://www.facebook.com/login/
# 2023-10-28 08:17:08,721 INFO:Crawling: https://messenger.com/
# 2023-10-28 08:17:10,092 INFO:Crawling: https://www.facebook.com/lite/
# 2023-10-28 08:17:10,503 INFO:Crawling: https://www.facebook.com/watch/
# 2023-10-28 08:17:10,786 INFO:Crawling: https://www.facebook.com/places/
# 2023-10-28 08:17:11,046 INFO:Crawling: https://www.facebook.com/games/
# 2023-10-28 08:17:11,406 INFO:Crawling: https://www.facebook.com/marketplace/
# 2023-10-28 08:17:11,705 INFO:Crawling: https://pay.facebook.com/
# 2023-10-28 08:17:13,159 INFO:Crawling: https://www.meta.com/
# 2023-10-28 08:17:13,846 INFO:Crawling: https://www.meta.com/quest/
# 2023-10-28 08:17:14,179 INFO:Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT2aQl5Bq38JXG4MHpgbxxq2BO1KceOitbese7PxRCMSqj2I-alavbXUcPra_wT2kD2pFp4EwDw3bXAohf_cefiC5qkTa0TN9d-KXNEguZ0Hn0cjXCpYhdIt5oqHZjEKmZmZ2Um9vnbrggTo
# 2023-10-28 08:17:14,439 INFO:Crawling: https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.threads.net%2F&h=AT2xaenNIb1jgPDsUIJHG66obdgi38PsGljA1iqH6BhqM9x49B5vkDNM8lMYRJMc4VVxsnCnDI13dzwGKIR1PtNCyiwkORIEndMjgswhW6bNr2KAgmLzwJeddklHcYr4saNhwdUwN4POYXmp
# 2023-10-28 08:17:14,642 INFO:Crawling: https://www.facebook.com/fundraisers/
# 2023-10-28 08:17:16,312 INFO:Crawling: https://www.facebook.com/biz/directory/
# 2023-10-28 08:17:17,571 INFO:Crawling: https://www.facebook.com/votinginformationcenter/?entry_point=c2l0ZQ%3D%3D
# 2023-10-28 08:17:18,362 INFO:Crawling: https://www.facebook.com/privacy/policy/?entry_point=facebook_page_footer
# 2023-10-28 08:17:19,174 INFO:Crawling: https://www.facebook.com/privacy/center/?entry_point=facebook_page_footer
# 2023-10-28 08:17:19,967 INFO:Crawling: https://www.facebook.com/groups/discover/
# 2023-10-28 08:17:21,130 INFO:Crawling: https://about.meta.com/
# 2023-10-28 08:17:22,394 INFO:Crawling: https://www.facebook.com/ad_campaign/landing.php?placement=pflo&campaign_id=402047449186&nav_source=unknown&extra_1=auto
# 2023-10-28 08:17:23,592 INFO:Crawling: https://www.facebook.com/pages/create/?ref_type=site_footer
# 2023-10-28 08:17:24,251 INFO:Crawling: https://developers.facebook.com/?ref=pf
# 2023-10-28 08:17:25,895 INFO:Crawling: https://www.facebook.com/careers/?ref=pf
# 2023-10-28 08:17:29,708 INFO:Crawling: https://www.facebook.com/policies/cookies/
# 2023-10-28 08:17:30,514 INFO:Crawling: https://www.facebook.com/help/568137493302217
# 2023-10-28 08:17:31,247 INFO:Crawling: https://www.facebook.com/policies?ref=pf
# 2023-10-28 08:17:32,522 INFO:Crawling: https://www.facebook.com/help/?ref=pf
# 2023-10-28 08:17:33,249 INFO:Crawling: help/637205020878504
# 2023-10-28 08:17:33,249 ERROR:Failed to crawl: help/637205020878504
# Traceback (most recent call last):
#   File "<ipython-input-2-e7734c85d5c6>", line 41, in run
#     self.crawl(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 32, in crawl
#     html = self.download_url(url)
#   File "<ipython-input-2-e7734c85d5c6>", line 16, in download_url
#     return requests.get(url).text
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 575, in request
#     prep = self.prepare_request(req)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/sessions.py", line 486, in prepare_request
#     p.prepare(
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 368, in prepare
#     self.prepare_url(url, params)
#   File "/home/jandogonzales/.local/lib/python3.8/site-packages/requests/models.py", line 439, in prepare_url
#     raise MissingSchema(
# requests.exceptions.MissingSchema: Invalid URL 'help/637205020878504': No scheme supplied. Perhaps you meant https://help/637205020878504?
# 2023-10-28 08:17:33,250 INFO:Crawling: https://www.facebook.com/settings
# 2023-10-28 08:17:34,068 INFO:Crawling: https://www.facebook.com/allactivity?privacy_source=activity_log_top_menu
# 2023-10-28 08:17:34,678 INFO:Crawling: https://www.HugeDomains.com/index.cfm
# 2023-10-28 08:17:34,981 INFO:Crawling: https://www.HugeDomains.com/domain_search.cfm
# 2023-10-28 08:17:36,313 INFO:Crawling: https://www.HugeDomains.com/domain_profile.cfm?d=DwRealty.com
# 2023-10-28 08:17:36,673 INFO:Crawling: https://www.HugeDomains.com/shopping_cart.cfm?d=DwRealty.com
# 2023-10-28 08:17:36,980 INFO:Crawling: https://www.HugeDomains.com/domain_profile.cfm?d=SkElectrical.com
# 2023-10-28 08:17:37,224 INFO:Crawling: https://www.HugeDomains.com/shopping_cart.cfm?d=SkElectrical.com
# 2023-10-28 08:17:37,528 INFO:Crawling: https://www.HugeDomains.com/domain_profile.cfm?d=GgcOnline.com
# 2023-10-28 08:17:37,903 INFO:Crawling: https://www.HugeDomains.com/shopping_cart.cfm?d=GgcOnline.com
# 2023-10-28 08:17:38,234 INFO:Crawling: https://www.HugeDomains.com/domain_profile.cfm?d=SaiConsultants.com
# 2023-10-28 08:17:38,462 INFO:Crawling: https://www.HugeDomains.com/shopping_cart.cfm?d=SaiConsultants.com
# 2023-10-28 08:17:38,818 INFO:Crawling: https://www.HugeDomains.com/domain_profile.cfm?d=ClickDi.com
# 2023-10-28 08:17:39,234 INFO:Crawling: https://www.HugeDomains.com/shopping_cart.cfm?d=ClickDi.com
# 2023-10-28 08:17:39,419 INFO:Crawling: https://www.HugeDomains.com/domain_profile.cfm?d=TopBoa.com
# 2023-10-28 08:17:40,872 INFO:Crawling: https://www.HugeDomains.com/shopping_cart.cfm?d=TopBoa.com
# 2023-10-28 08:17:41,220 INFO:Crawling: https://www.HugeDomains.com/case-study-upgraders.cfm
# 2023-10-28 08:17:41,443 INFO:Crawling: https://www.HugeDomains.com/case-study-crypto-adventure.cfm
# 2023-10-28 08:17:41,652 INFO:Crawling: https://www.HugeDomains.com/get-more.cfm
# 2023-10-28 08:17:41,859 INFO:Crawling: https://www.HugeDomains.com/faq.cfm
# 2023-10-28 08:17:42,133 INFO:Crawling: https://www.namebright.com
# 2023-10-28 08:17:42,633 INFO:Crawling: https://www.HugeDomains.com/how-domain-transfers-work.cfm
# 2023-10-28 08:17:42,858 INFO:Crawling: https://www.HugeDomains.com/domain-info.cfm
# 2023-10-28 08:17:43,071 INFO:Crawling: https://www.HugeDomains.com/about.cfm
# 2023-10-28 08:17:43,283 INFO:Crawling: https://www.HugeDomains.com/company_profile.cfm
# 2023-10-28 08:17:43,497 INFO:Crawling: https://www.HugeDomains.com/contact.cfm
# 2023-10-28 08:17:43,684 INFO:Crawling: https://www.HugeDomains.com/payment-plan-login.cfm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e7734c85d5c6> in <module>
#      46
#      47 if __name__ == '__main__':
# ---> 48     Crawler(urls=['https://www.imbd.com/']).run()
#      49
#
# <ipython-input-2-e7734c85d5c6> in run(self)
#      39             logging.info(f'Crawling: {url}')
#      40             try:
# ---> 41                 self.crawl(url)
#      42             except Exception:
#      43                 logging.exception(f'Failed to crawl: {url}')
#
# <ipython-input-2-e7734c85d5c6> in crawl(self, url)
#      30
#      31     def crawl(self, url):
# ---> 32         html = self.download_url(url)
#      33         for url in self.get_linked_urls(url, html):
#      34             self.add_url_to_visit(url)
#
# <ipython-input-2-e7734c85d5c6> in download_url(self, url)
#      14
#      15     def download_url(self, url):
# ---> 16         return requests.get(url).text
#      17
#      18     def get_linked_urls(self, url, html):
#
# ~/.local/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/.local/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# ~/.local/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788
#     789             # Make the request on the HTTPConnection object
# --> 790             response = self._make_request(
#     791                 conn,
#     792                 method,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465             # Trigger any extra validation we need to do.
#     466             try:
# --> 467                 self._validate_conn(conn)
#     468             except (SocketTimeout, BaseSSLError) as e:
#     469                 self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1090         # Force connect early to allow us to validate the connection.
#    1091         if conn.is_closed:
# -> 1092             conn.connect()
#    1093
#    1094         if not conn.is_verified:
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     609     def connect(self) -> None:
#     610         sock: socket.socket | ssl.SSLSocket
# --> 611         self.sock = sock = self._new_conn()
#     612         server_hostname: str = self.host
#     613         tls_in_tls = False
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     201         """
#     202         try:
# --> 203             sock = connection.create_connection(
#     204                 (self._dns_host, self.port),
#     205                 self.timeout,
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#      75             err = None
#
# KeyboardInterrupt:
